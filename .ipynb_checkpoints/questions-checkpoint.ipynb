# %%
import pandas as pd
from sklearn import svm
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df=pd.read_csv("assignment_dataset.csv")
len(df)
# Out:
# 129971

# %%
df[df.isnull().any(axis=1)] #rows where NAN present
# Out:
#                                                     title             variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)         White Blend
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 7                   Trimbach 2012 Gewurztraminer (Alsace)      Gewürztraminer
# 11                Leon Beyer 2012 Gewurztraminer (Alsace)      Gewürztraminer
# 12      Louis M. Martini 2012 Cabernet Sauvignon (Alex...  Cabernet Sauvignon
# ...                                                   ...                 ...
# 129955            Dog Point 2012 Chardonnay (Marlborough)          Chardonnay
# 129961                        COS 2013 Frappato (Sicilia)            Frappato
# 129964  Domaine Ehrhart 2013 Domaine Saint-Rémy Herren...      Gewürztraminer
# 129967                  Citation 2004 Pinot Noir (Oregon)          Pinot Noir
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          Pinot Gris
#
#                          designation      country           province  \
# 0                       Vulkà Bianco        Italy  Sicily & Sardinia
# 2                                NaN           US             Oregon
# 7                                NaN       France             Alsace
# 11                               NaN       France             Alsace
# 12                               NaN           US         California
# ...                              ...          ...                ...
# 129955                           NaN  New Zealand        Marlborough
# 129961                           NaN        Italy  Sicily & Sardinia
# 129964  Domaine Saint-Rémy Herrenweg       France             Alsace
# 129967                           NaN           US             Oregon
# 129969                           NaN       France             Alsace
#
#                                               description  price  \
# 0       Aromas include tropical fruit, broom, brimston...    NaN
# 2       Tart and snappy, the flavors of lime flesh and...   14.0
# 7       This dry and restrained wine offers spice in p...   24.0
# 11      This is a dry wine, very spicy, with a tight, ...   30.0
# 12      Slightly reduced, this wine offers a chalky, t...   34.0
# ...                                                   ...    ...
# 129955  Like Dog Point's 2011 Chardonnay, this wine is...   40.0
# 129961  Intense aromas of wild cherry, baking spice, t...   30.0
# 129964  Initially quite muted, this wine slowly develo...    NaN
# 129967  Citation is given as much as a decade of bottl...   75.0
# 129969  A dry style of Pinot Gris, this is crisp with ...   32.0
#
#                       winery     taster_name  points
# 0                    Nicosia   Kerin O’Keefe      87
# 2                  Rainstorm    Paul Gregutt      87
# 7                   Trimbach      Roger Voss      87
# 11                Leon Beyer      Roger Voss      87
# 12          Louis M. Martini  Virginie Boone      87
# ...                      ...             ...     ...
# 129955             Dog Point  Joe Czerwinski      90
# 129961                   COS   Kerin O’Keefe      90
# 129964       Domaine Ehrhart      Roger Voss      90
# 129967              Citation    Paul Gregutt      90
# 129969  Domaine Marcel Deiss      Roger Voss      90
#
# [60052 rows x 10 columns]

# %%
df.columns[df.isna().any()].tolist() #find columns which has NaN
# Out:
# ['variety', 'designation', 'country', 'province', 'price', 'taster_name']

# %%
#missing value plot

# %%
df[df['variety'].isnull()] #row where variety is missing
df = df[df['variety'].notna()] #revoing the row where variety is NaN

# %%
df.designation.fillna(df.province, inplace=True) #replace designation with province replace with unknown
df[df['designation'].isnull()] #find remaining row with designation NaN
df=df[df['designation'].notna()] #removing nan

# %%
print(len(df[df['country'].isnull()])) #rows where country 
df=df[df['country'].notna()]
# Out:
# 52

# %%
print(len(df[df['province'].isnull()]))
# Out:
# 0

# %%
print(len(df[df['price'].isnull()]))
price_not_present=df[df['price'].isnull()]
d_p=df[df['price'].notna()]#removing the data where price is not present 
len(d_p)
# Out:
# 8992
# 120915

# %%
d_p[d_p['taster_name'].isnull()]  #rows where tester name is missing
# len(df.taster_name.unique())
# Out:
#                                                     title  \
# 33      Envolve 2010 Puma Springs Vineyard Red (Dry Cr...
# 34           Envolve 2011 Sauvignon Blanc (Sonoma Valley)
# 37      Feudi del Pisciotto 2010 Missoni Cabernet Sauv...
# 38      Feudi di San Marzano 2011 I Tratturi Primitivo...
# 39      Feudo di Santa Tresa 2011 Purato Made With Org...
# ...                                                   ...
# 129852  MandraRossa 2006 Cabernet Sauvignon-Shiraz (Si...
# 129914   Fritz 2005 Cabernet Sauvignon (Dry Creek Valley)
# 129920  Pali 2006 Fiddlestix Vineyard Pinot Noir (Sta....
# 129929  Col Vetoraz Spumanti NV  Prosecco Superiore di...
# 129940  Standish 2006 Watson Vineyard Chardonnay (Mend...
#
#                           variety                      designation country  \
# 33                      Red Blend            Puma Springs Vineyard      US
# 34                Sauvignon Blanc                       California      US
# 37             Cabernet Sauvignon                          Missoni   Italy
# 38                      Primitivo                       I Tratturi   Italy
# 39                   Nero d'Avola  Purato Made With Organic Grapes   Italy
# ...                           ...                              ...     ...
# 129852  Cabernet Sauvignon-Shiraz                Sicily & Sardinia   Italy
# 129914         Cabernet Sauvignon                       California      US
# 129920                 Pinot Noir              Fiddlestix Vineyard      US
# 129929                   Prosecco                           Veneto   Italy
# 129940                 Chardonnay                  Watson Vineyard      US
#
#                  province                                        description  \
# 33             California  Rustic and dry, this has flavors of berries, c...
# 34             California  This shows a tart, green gooseberry flavor tha...
# 37      Sicily & Sardinia  This concentrated Cabernet offers aromas of cu...
# 38         Southern Italy  Inky in color, this wine has plump aromas of r...
# 39      Sicily & Sardinia  Part of the natural wine movement, this wine i...
# ...                   ...                                                ...
# 129852  Sicily & Sardinia  Here's an easy blend of Cabernet Sauvignon and...
# 129914         California  Fritz has made tremendous progress with Cab ov...
# 129920         California  Shows the clean, citrus acid juiciness and sil...
# 129929             Veneto  This luminous sparkler has a sweet, fruit-forw...
# 129940         California  This is the winery's bells and whistles Chardo...
#
#         price                winery taster_name  points
# 33       50.0               Envolve         NaN      86
# 34       20.0               Envolve         NaN      86
# 37       21.0   Feudi del Pisciotto         NaN      86
# 38       11.0  Feudi di San Marzano         NaN      86
# 39       12.0  Feudo di Santa Tresa         NaN      86
# ...       ...                   ...         ...     ...
# 129852   10.0           MandraRossa         NaN      86
# 129914   35.0                 Fritz         NaN      91
# 129920   48.0                  Pali         NaN      91
# 129929   38.0  Col Vetoraz Spumanti         NaN      91
# 129940   36.0              Standish         NaN      91
#
# [24495 rows x 10 columns]

# %%
#lowercase everything
d_l = d_p.apply(lambda x: x.str.lower() if x.dtype=='object' else x)
print(len(d_l.country.unique()))
print(len(d_l.variety.unique()))
print(len(d_l.province.unique()))
print(len(d_l.winery.unique()))
# Out:
# 42
# 691
# 422
# 15820

# %%
d_l.columns[df.isna().any()].tolist() #find columns which has NaN
d_l.reset_index(drop=True, inplace=True)

# %%
def encode_and_bind(original_dataframe, feature_to_encode):
    dummies = pd.get_dummies(original_dataframe[[feature_to_encode]])
    res=dummies
#     res = pd.concat([original_dataframe, dummies], axis=1)
    return(res)
varieties=encode_and_bind(d_l,'variety')
countries=encode_and_bind(d_l, 'country')
proviences=encode_and_bind(d_l, 'province')
# wineries=encode_and_bind(d_l,'winery')

# %%
p = d_l['points']/100 #scaling

# %%
x=pd.concat([p,countries, proviences, varieties], axis=1, ignore_index=True)
y=d_l['price'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
reg=linear_model.LinearRegression().fit(X_train,y_train)
reg.score(X_train,y_train)
# Out:
# 0.2635141580609417

# %%
bes = linear_model.BayesianRidge(compute_score=True)
bes.fit(X_train, y_train)

# %%
regr = RandomForestRegressor(n_estimators=1000,max_depth=500, random_state=0)
regr.fit(X_train, y_train)
# Out:
# C:\Users\ARNAB\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-cfe6f61be4f7> in <module>
#       1 regr = RandomForestRegressor(n_estimators=1000,max_depth=500, random_state=0)
# ----> 2 regr.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     328                     t, self, X, y, sample_weight, i, len(trees),
#     329                     verbose=self.verbose, class_weight=self.class_weight)
# --> 330                 for i, t in enumerate(trees))
#     331
#     332             # Collect newly grown trees
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     116             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     117
# --> 118         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     119     else:
#     120         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1155             sample_weight=sample_weight,
#    1156             check_input=check_input,
# -> 1157             X_idx_sorted=X_idx_sorted)
#    1158         return self
#    1159
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     378                                            min_impurity_split)
#     379
# --> 380         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     381
#     382         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
regr.score(X_train,y_train)

# %%
d_l
# Out:
#                                                     title             variety  \
# 0           quinta dos avidagos 2011 avidagos red (douro)      portuguese red
# 1           rainstorm 2013 pinot gris (willamette valley)          pinot gris
# 2       st. julian 2013 reserve late harvest riesling ...            riesling
# 3       sweet cheeks 2012 vintner's reserve wild child...          pinot noir
# 4       tandem 2011 ars in vitro tempranillo-merlot (n...  tempranillo-merlot
# ...                                                   ...                 ...
# 120910  dr. h. thanisch (erben müller-burggraef) 2013 ...            riesling
# 120911                  citation 2004 pinot noir (oregon)          pinot noir
# 120912  domaine gresser 2013 kritt gewurztraminer (als...      gewürztraminer
# 120913      domaine marcel deiss 2012 pinot gris (alsace)          pinot gris
# 120914  domaine schoffit 2012 lieu-dit harth cuvée car...      gewürztraminer
#
#                                    designation   country        province  \
# 0                                     avidagos  portugal           douro
# 1                                       oregon        us          oregon
# 2                         reserve late harvest        us        michigan
# 3           vintner's reserve wild child block        us          oregon
# 4                                 ars in vitro     spain  northern spain
# ...                                        ...       ...             ...
# 120910  brauneberger juffer-sonnenuhr spätlese   germany           mosel
# 120911                                  oregon        us          oregon
# 120912                                   kritt    france          alsace
# 120913                                  alsace    france          alsace
# 120914           lieu-dit harth cuvée caroline    france          alsace
#
#                                               description  price  \
# 0       this is ripe and fruity, a wine that is smooth...   15.0
# 1       tart and snappy, the flavors of lime flesh and...   14.0
# 2       pineapple rind, lemon pith and orange blossom ...   13.0
# 3       much like the regular bottling from 2012, this...   65.0
# 4       blackberry and raspberry aromas show a typical...   15.0
# ...                                                   ...    ...
# 120910  notes of honeysuckle and cantaloupe sweeten th...   28.0
# 120911  citation is given as much as a decade of bottl...   75.0
# 120912  well-drained gravel soil gives this wine its c...   30.0
# 120913  a dry style of pinot gris, this is crisp with ...   32.0
# 120914  big, rich and off-dry, this is powered by inte...   21.0
#
#                                           winery         taster_name  points
# 0                            quinta dos avidagos          roger voss      87
# 1                                      rainstorm        paul gregutt      87
# 2                                     st. julian  alexander peartree      87
# 3                                   sweet cheeks        paul gregutt      87
# 4                                         tandem   michael schachner      87
# ...                                          ...                 ...     ...
# 120910  dr. h. thanisch (erben müller-burggraef)  anna lee c. iijima      90
# 120911                                  citation        paul gregutt      90
# 120912                           domaine gresser          roger voss      90
# 120913                      domaine marcel deiss          roger voss      90
# 120914                          domaine schoffit          roger voss      90
#
# [120915 rows x 10 columns]

# %%
#label encoder 
#grid search 
#keras deeplearning

# %%
#variety clustering 
#the country, price, point histogram 
#pie chart 
#word cloud per variety

# %%
#predict the wine type from the description
